# %% [markdown]
# <a href="https://colab.research.google.com/github/venkateshsureshcks/coffee_machine/blob/main/project_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

url = "https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/001/551/original/delhivery_data.csv?1642751181"
df = pd.read_csv(url)
df
# Out:
#             data          trip_creation_time  \
# 0       training  2018-09-20 02:35:36.476840
# 1       training  2018-09-20 02:35:36.476840
# 2       training  2018-09-20 02:35:36.476840
# 3       training  2018-09-20 02:35:36.476840
# 4       training  2018-09-20 02:35:36.476840
# ...          ...                         ...
# 144862  training  2018-09-20 16:24:28.436231
# 144863  training  2018-09-20 16:24:28.436231
# 144864  training  2018-09-20 16:24:28.436231
# 144865  training  2018-09-20 16:24:28.436231
# 144866  training  2018-09-20 16:24:28.436231
#
#                                       route_schedule_uuid route_type  \
# 0       thanos::sroute:eb7bfc78-b351-4c0e-a951-fa3d5c3...    Carting
# 1       thanos::sroute:eb7bfc78-b351-4c0e-a951-fa3d5c3...    Carting
# 2       thanos::sroute:eb7bfc78-b351-4c0e-a951-fa3d5c3...    Carting
# 3       thanos::sroute:eb7bfc78-b351-4c0e-a951-fa3d5c3...    Carting
# 4       thanos::sroute:eb7bfc78-b351-4c0e-a951-fa3d5c3...    Carting
# ...

# %%
df.isnull().sum() / len(df) * 100
# Out:
# data                              0.000000
# trip_creation_time                0.000000
# route_schedule_uuid               0.000000
# route_type                        0.000000
# trip_uuid                         0.000000
# source_center                     0.000000
# source_name                       0.202254
# destination_center                0.000000
# destination_name                  0.180165
# od_start_time                     0.000000
# od_end_time                       0.000000
# start_scan_to_end_scan            0.000000
# is_cutoff                         0.000000
# cutoff_factor                     0.000000
# cutoff_timestamp                  0.000000
# actual_distance_to_destination    0.000000
# actual_time                       0.000000
# osrm_time                         0.000000
# osrm_distance                     0.000000
# factor                            0.000000
# segment_actual_time               0.000000
# segment_osrm_time                 0.000000
# ...

# %%
df.shape[0], df.shape[1]
# Out:
# (144867, 24)

# %%
df.describe()
# Out:
#        start_scan_to_end_scan  cutoff_factor  actual_distance_to_destination  \
# count           144867.000000  144867.000000                   144867.000000
# mean               961.262986     232.926567                      234.073372
# std               1037.012769     344.755577                      344.990009
# min                 20.000000       9.000000                        9.000045
# 25%                161.000000      22.000000                       23.355874
# 50%                449.000000      66.000000                       66.126571
# 75%               1634.000000     286.000000                      286.708875
# max               7898.000000    1927.000000                     1927.447705
#
#          actual_time      osrm_time  osrm_distance         factor  \
# count  144867.000000  144867.000000  144867.000000  144867.000000
# mean      416.927527     213.868272     284.771297       2.120107
# std       598.103621     308.011085     421.119294       1.715421
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144867 entries, 0 to 144866
# Data columns (total 24 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   data                            144867 non-null  object
#  1   trip_creation_time              144867 non-null  object
#  2   route_schedule_uuid             144867 non-null  object
#  3   route_type                      144867 non-null  object
#  4   trip_uuid                       144867 non-null  object
#  5   source_center                   144867 non-null  object
#  6   source_name                     144574 non-null  object
#  7   destination_center              144867 non-null  object
#  8   destination_name                144606 non-null  object
#  9   od_start_time                   144867 non-null  object
#  10  od_end_time                     144867 non-null  object
#  11  start_scan_to_end_scan          144867 non-null  float64
# ...

# %%
df = df.fillna("Unknown")

# %%
df[['trip_creation_time', 'od_start_time','od_end_time']] = df[['trip_creation_time', 'od_start_time','od_end_time']].apply(pd.to_datetime)

# %%
df['cutoff_timestamp'] = pd.to_datetime(df['cutoff_timestamp'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144867 entries, 0 to 144866
# Data columns (total 24 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   data                            144867 non-null  object
#  1   trip_creation_time              144867 non-null  datetime64[ns]
#  2   route_schedule_uuid             144867 non-null  object
#  3   route_type                      144867 non-null  object
#  4   trip_uuid                       144867 non-null  object
#  5   source_center                   144867 non-null  object
#  6   source_name                     144867 non-null  object
#  7   destination_center              144867 non-null  object
#  8   destination_name                144867 non-null  object
#  9   od_start_time                   144867 non-null  datetime64[ns]
#  10  od_end_time                     144867 non-null  datetime64[ns]
# ...

# %%
df = df.drop_duplicates()

# %%
df["trip_uuid"].nunique()
# Out:
# 14817

# %%
df["source_center"].nunique()
# Out:
# 1508

# %%
df["destination_center"].nunique()
# Out:
# 1481

# %%
df.groupby("source_center")['source_name'].unique()
# Out:
# source_center
# IND000000AAL                [Pune_PC (Maharashtra)]
# IND000000AAQ     [Barasat_KrshnNgr_D (West Bengal)]
# IND000000AAS        [Bongaigaon_Chpaguri_D (Assam)]
# IND000000AAZ    [Buldhana_Thsil3PL_D (Maharashtra)]
# IND000000ABA           [Cochin_Chtrpuza_D (Kerala)]
#                                ...
# IND854105AAB          [Katihar_Central_D_2 (Bihar)]
# IND854311AAA             [Araria_Wardn13_D (Bihar)]
# IND854326AAB           [Purnia_Central_H_2 (Bihar)]
# IND854334AAA       [Raniganj_Central_DPP_1 (Bihar)]
# IND854335AAA     [Narpatganj_Central_DPP_1 (Bihar)]
# Name: source_name, Length: 1508, dtype: object

# %%
df.groupby("destination_center")['destination_name'].unique()
# Out:
# destination_center
# IND000000AAL                [Pune_PC (Maharashtra)]
# IND000000AAS        [Bongaigaon_Chpaguri_D (Assam)]
# IND000000AAZ    [Buldhana_Thsil3PL_D (Maharashtra)]
# IND000000ABA           [Cochin_Chtrpuza_D (Kerala)]
# IND000000ABD         [Pallakad_ChndrNgr_D (Kerala)]
#                                ...
# IND854105AAB          [Katihar_Central_D_2 (Bihar)]
# IND854311AAA             [Araria_Wardn13_D (Bihar)]
# IND854326AAB           [Purnia_Central_H_2 (Bihar)]
# IND854334AAA       [Raniganj_Central_DPP_1 (Bihar)]
# IND854335AAA     [Narpatganj_Central_DPP_1 (Bihar)]
# Name: destination_name, Length: 1481, dtype: object

# %%
df.groupby("trip_uuid")['destination_name'].unique()
# Out:
# trip_uuid
# trip-153671041653548748    [Kanpur_Central_H_6 (Uttar Pradesh), Gurgaon_B...
# trip-153671042288605164    [Doddablpur_ChikaDPP_D (Karnataka), Chikblapur...
# trip-153671043369099517    [Gurgaon_Bilaspur_HB (Haryana), Chandigarh_Meh...
# trip-153671046011330457                     [Mumbai_MiraRd_IP (Maharashtra)]
# trip-153671052974046625    [Hospet (Karnataka), Sandur_WrdN1DPP_D (Karnat...
#                                                  ...
# trip-153861095625827784    [Zirakpur_DC (Punjab), Chandigarh_Mehmdpur_H (...
# trip-153861104386292051                     [Faridabad_Blbgarh_DC (Haryana)]
# trip-153861106442901555    [Kanpur_GovndNgr_DC (Uttar Pradesh), Kanpur_Ce...
# trip-153861115439069069    [Eral_Busstand_D (Tamil Nadu), Tirchchndr_Shnm...
# trip-153861118270144424    [Sandur_WrdN1DPP_D (Karnataka), Bellary_Dc (Ka...
# Name: destination_name, Length: 14817, dtype: object

# %%
df.groupby("trip_uuid")['actual_time'].count()
# Out:
# trip_uuid
# trip-153671041653548748    39
# trip-153671042288605164     9
# trip-153671043369099517    89
# trip-153671046011330457     2
# trip-153671052974046625     7
#                            ..
# trip-153861095625827784     7
# trip-153861104386292051     2
# trip-153861106442901555     6
# trip-153861115439069069    17
# trip-153861118270144424     4
# Name: actual_time, Length: 14817, dtype: int64

# %%
df.groupby("trip_uuid")['source_name'].sum()
# Out:
# trip_uuid
# trip-153671041653548748    Bhopal_Trnsport_H (Madhya Pradesh)Bhopal_Trnsp...
# trip-153671042288605164    Tumkur_Veersagr_I (Karnataka)Tumkur_Veersagr_I...
# trip-153671043369099517    Bangalore_Nelmngla_H (Karnataka)Bangalore_Nelm...
# trip-153671046011330457     Mumbai Hub (Maharashtra)Mumbai Hub (Maharashtra)
# trip-153671052974046625    Bellary_Dc (Karnataka)Bellary_Dc (Karnataka)Be...
#                                                  ...
# trip-153861095625827784    Chandigarh_Mehmdpur_H (Punjab)Chandigarh_Mehmd...
# trip-153861104386292051    FBD_Balabhgarh_DPC (Haryana)FBD_Balabhgarh_DPC...
# trip-153861106442901555    Kanpur_Central_H_6 (Uttar Pradesh)Kanpur_Centr...
# trip-153861115439069069    Tirunelveli_VdkkuSrt_I (Tamil Nadu)Tirunelveli...
# trip-153861118270144424    Hospet (Karnataka)Hospet (Karnataka)Sandur_Wrd...
# Name: source_name, Length: 14817, dtype: object

# %%
df[df["destination_center"] == "IND000000AAL"]['destination_name'].head()
# Out:
# 8077     Pune_PC (Maharashtra)
# 8078     Pune_PC (Maharashtra)
# 8079     Pune_PC (Maharashtra)
# 20551    Pune_PC (Maharashtra)
# 20552    Pune_PC (Maharashtra)
# Name: destination_name, dtype: object

# %%
suma = df[df["trip_uuid"] == "trip-153741093647649320"]['destination_name']
suma
# Out:
# 0    Khambhat_MotvdDPP_D (Gujarat)
# 1    Khambhat_MotvdDPP_D (Gujarat)
# 2    Khambhat_MotvdDPP_D (Gujarat)
# 3    Khambhat_MotvdDPP_D (Gujarat)
# 4    Khambhat_MotvdDPP_D (Gujarat)
# 5       Anand_Vaghasi_IP (Gujarat)
# 6       Anand_Vaghasi_IP (Gujarat)
# 7       Anand_Vaghasi_IP (Gujarat)
# 8       Anand_Vaghasi_IP (Gujarat)
# 9       Anand_Vaghasi_IP (Gujarat)
# Name: destination_name, dtype: object

# %%
df['destination'] = df['destination_center']+'/'+ df['destination_name']

# %%
df["source"] = df['source_center']+'/'+ df['source_name']

# %% [markdown]
# **Destination Name: Split and extract features out of destination. City-place-code (State)**

# %%
df['destination_city'] = df['destination'].str.extract(r'\((.*?)\)')
df['destination_place'] = df['destination'].str.extract(r'/([^()]+) \(')
df['destination_code'] = df['destination'].str.extract(r'^([^/]+)')

# %%
df[['destination_city','destination_place', 'destination_code']].head()
# Out:
#   destination_city    destination_place destination_code
# 0          Gujarat  Khambhat_MotvdDPP_D     IND388620AAB
# 1          Gujarat  Khambhat_MotvdDPP_D     IND388620AAB
# 2          Gujarat  Khambhat_MotvdDPP_D     IND388620AAB
# 3          Gujarat  Khambhat_MotvdDPP_D     IND388620AAB
# 4          Gujarat  Khambhat_MotvdDPP_D     IND388620AAB

# %% [markdown]
# **Source Name: Split and extract features out of destination. City-place-code (State)**

# %%
df['source_city'] = df['source'].str.extract(r'\((.*?)\)')
df['source_place'] = df['source'].str.extract(r'/([^()]+) \(')
df['source_code'] = df['source'].str.extract(r'^([^/]+)')

# %%
df[['source_city','source_place', 'source_code']].head()
# Out:
#   source_city      source_place   source_code
# 0     Gujarat  Anand_VUNagar_DC  IND388121AAA
# 1     Gujarat  Anand_VUNagar_DC  IND388121AAA
# 2     Gujarat  Anand_VUNagar_DC  IND388121AAA
# 3     Gujarat  Anand_VUNagar_DC  IND388121AAA
# 4     Gujarat  Anand_VUNagar_DC  IND388121AAA

# %% [markdown]
# **Trip_creation_time: Extract features like month, year and day etc**

# %%
df['trip_month'] = df['trip_creation_time'].dt.month
df['trip_year'] = df['trip_creation_time'].dt.year
df['trip_day'] = df['trip_creation_time'].dt.day
df['trip_time'] = df['trip_creation_time'].dt.hour * 3600

# %%
df[['trip_month','trip_year', 'trip_day', 'trip_time']].head()
# Out:
#    trip_month  trip_year  trip_day  trip_time
# 0           9       2018        20       7200
# 1           9       2018        20       7200
# 2           9       2018        20       7200
# 3           9       2018        20       7200
# 4           9       2018        20       7200

# %% [markdown]
# **Calculate the time taken between od_start_time and od_end_time and keep it as a feature. Drop the original columns, if required**

# %%
df['od_start_time']
# Out:
# 0        2018-09-20 03:21:32.418600
# 1        2018-09-20 03:21:32.418600
# 2        2018-09-20 03:21:32.418600
# 3        2018-09-20 03:21:32.418600
# 4        2018-09-20 03:21:32.418600
#                     ...
# 144862   2018-09-20 16:24:28.436231
# 144863   2018-09-20 16:24:28.436231
# 144864   2018-09-20 16:24:28.436231
# 144865   2018-09-20 16:24:28.436231
# 144866   2018-09-20 16:24:28.436231
# Name: od_start_time, Length: 144867, dtype: datetime64[ns]

# %%
df['time_taken'] = df['od_end_time'] - df['od_start_time']
df['time_taken'] = df['time_taken'].dt.total_seconds() / 60
df['time_taken'].round(0)
# Out:
# 0          86.0
# 1          86.0
# 2          86.0
# 3          86.0
# 4          86.0
#           ...
# 144862    428.0
# 144863    428.0
# 144864    428.0
# 144865    428.0
# 144866    428.0
# Name: time_taken, Length: 144867, dtype: float64

# %%
df['start_scan_to_end_scan']
# Out:
# 0          86.0
# 1          86.0
# 2          86.0
# 3          86.0
# 4          86.0
#           ...
# 144862    427.0
# 144863    427.0
# 144864    427.0
# 144865    427.0
# 144866    427.0
# Name: start_scan_to_end_scan, Length: 144867, dtype: float64

# %% [markdown]
# ***Compare the difference between Point a. and start_scan_to_end_scan. Do hypothesis testing/ Visual analysis to check.***

# %%
df['time_taken'] - df['start_scan_to_end_scan']
# Out:
# 0         0.213637
# 1         0.213637
# 2         0.213637
# 3         0.213637
# 4         0.213637
#             ...
# 144862    0.686364
# 144863    0.686364
# 144864    0.686364
# 144865    0.686364
# 144866    0.686364
# Length: 144867, dtype: float64

# %%
from scipy.stats import ttest_rel, ttest_ind
t_stat, p_value = ttest_rel(df['time_taken'], df['start_scan_to_end_scan'])
print("t-statistic:", t_stat)
print("p-value:", p_value)
# Out:
# t-statistic: 651.1832057297116
# p-value: 0.0

# %%
if p_value > 0.05:
    print("The distributions are not significantly different.")
else:
    print("The distributions are significantly different.")
# Out:
# The distributions are significantly different.

# %%
# Boxplot
plt.figure(figsize=(10, 5))
sns.boxplot(data=df[['time_taken', 'start_scan_to_end_scan']])
plt.title('Boxplot: time_taken vs start_scan_to_end_scan')
plt.show()

# KDE Plot (Distribution)
plt.figure(figsize=(10, 5))
sns.kdeplot(df['time_taken'], label='time_taken', shade=True)
sns.kdeplot(df['start_scan_to_end_scan'], label='start_scan_to_end_scan', shade=True)
plt.title('KDE Distribution Comparison')
plt.legend()
plt.show()
# Out:
# /tmp/ipython-input-175-829570077.py:9: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['time_taken'], label='time_taken', shade=True)
# /tmp/ipython-input-175-829570077.py:10: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['start_scan_to_end_scan'], label='start_scan_to_end_scan', shade=True)

# %% [markdown]
# **Do hypothesis testing/ visual analysis between actual_time aggregated value and OSRM time aggregated value (aggregated values are the values you’ll get after merging the rows on the basis of trip_uuid)**

# %%
df['actual_time'] - df['osrm_time']
# Out:
# 0           3.0
# 1           4.0
# 2          12.0
# 3          22.0
# 4          24.0
#           ...
# 144862     34.0
# 144863     44.0
# 144864     52.0
# 144865     60.0
# 144866    331.0
# Length: 144867, dtype: float64

# %%
actual_agg = df.groupby("trip_uuid")['actual_time'].sum()
actual_agg
# Out:
# trip_uuid
# trip-153671041653548748     15682.0
# trip-153671042288605164       399.0
# trip-153671043369099517    112225.0
# trip-153671046011330457        82.0
# trip-153671052974046625       556.0
#                              ...
# trip-153861095625827784       186.0
# trip-153861104386292051        33.0
# trip-153861106442901555       549.0
# trip-153861115439069069       600.0
# trip-153861118270144424       350.0
# Name: actual_time, Length: 14817, dtype: float64

# %%
osrm_time_agg = df.groupby("trip_uuid")['osrm_time'].sum()
osrm_time_agg
# Out:
# trip_uuid
# trip-153671041653548748     7787.0
# trip-153671042288605164      210.0
# trip-153671043369099517    65768.0
# trip-153671046011330457       24.0
# trip-153671052974046625      207.0
#                             ...
# trip-153861095625827784      148.0
# trip-153861104386292051       19.0
# trip-153861106442901555      134.0
# trip-153861115439069069      446.0
# trip-153861118270144424      106.0
# Name: osrm_time, Length: 14817, dtype: float64

# %%
f_stats, P_val = ttest_rel(actual_agg.values, osrm_time_agg.values)
print("t-statistic:", t_stat)
print("p-value:", p_value)
# Out:
# t-statistic: 651.1832057297116
# p-value: 0.0

# %%
if p_value > 0.05:
    print("The distributions are not significantly different.")
else:
    print("The distributions are significantly different.")
# Out:
# The distributions are significantly different.

# %%
plt.figure(figsize=(10, 6))
plt.plot(actual_agg.values.ravel()[:25], label='Actual Time', marker='o')
plt.plot(osrm_time_agg.values.ravel()[:25], label='OSRM Time', marker='x')
plt.title("Line Plot: Actual vs OSRM Time (First 25 Trips)")
plt.xlabel("Trip Index")
plt.ylabel("Time")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Do hypothesis testing/ visual analysis between actual_time aggregated value and segment actual time aggregated value (aggregated values are the values you’ll get after merging the rows on the basis of trip_uuid)**

# %%
df['actual_time'].head()
# Out:
# 0    14.0
# 1    24.0
# 2    40.0
# 3    62.0
# 4    68.0
# Name: actual_time, dtype: float64

# %%
df['segment_actual_time'].head()
# Out:
# 0    14.0
# 1    10.0
# 2    16.0
# 3    21.0
# 4     6.0
# Name: segment_actual_time, dtype: float64

# %%
segment_actualtime_agg = df.groupby('trip_uuid')['segment_actual_time'].sum()
segment_actualtime_agg.head()
# Out:
# trip_uuid
# trip-153671041653548748    1548.0
# trip-153671042288605164     141.0
# trip-153671043369099517    3308.0
# trip-153671046011330457      59.0
# trip-153671052974046625     340.0
# Name: segment_actual_time, dtype: float64

# %%
actualtime_agg = df.groupby('trip_uuid')['actual_time'].sum()
actualtime_agg.head()
# Out:
# trip_uuid
# trip-153671041653548748     15682.0
# trip-153671042288605164       399.0
# trip-153671043369099517    112225.0
# trip-153671046011330457        82.0
# trip-153671052974046625       556.0
# Name: actual_time, dtype: float64

# %%
actual_agg.head()
# Out:
# trip_uuid
# trip-153671041653548748     15682.0
# trip-153671042288605164       399.0
# trip-153671043369099517    112225.0
# trip-153671046011330457        82.0
# trip-153671052974046625       556.0
# Name: actual_time, dtype: float64

# %%
segment_actualtime_agg.head()
# Out:
# trip_uuid
# trip-153671041653548748    1548.0
# trip-153671042288605164     141.0
# trip-153671043369099517    3308.0
# trip-153671046011330457      59.0
# trip-153671052974046625     340.0
# Name: segment_actual_time, dtype: float64

# %%
f_stats, P_val = ttest_rel(actual_agg.values, segment_actualtime_agg.values)
print("t-statistic:", t_stat)
print("p-value:", p_value)
# Out:
# t-statistic: 651.1832057297116
# p-value: 0.0

# %%
if p_value > 0.05:
    print("The distributions are not significantly different.")
else:
    print("The distributions are significantly different.")
# Out:
# The distributions are significantly different.

# %%
plt.figure(figsize=(10, 6))
plt.plot(actual_agg.values.ravel()[:25], label='Actual Time', marker='o')
plt.plot(segment_actualtime_agg.values.ravel()[:25], label='Segment actual Time', marker='x')
plt.title("Line Plot: Actual vs segment_actualtime (First 25 Trips)")
plt.xlabel("Trip Index")
plt.ylabel("Time")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Do hypothesis testing/ visual analysis between osrm distance aggregated value and segment osrm distance aggregated value (aggregated values are the values you’ll get after merging the rows on the basis of trip_uuid)**

# %%
osrm_dis_agg = df.groupby('trip_uuid')['osrm_distance'].sum()
osrm_dis_agg.head()
# Out:
# trip_uuid
# trip-153671041653548748    10577.7647
# trip-153671042288605164      269.4308
# trip-153671043369099517    89447.2488
# trip-153671046011330457       31.6475
# trip-153671052974046625      266.2914
# Name: osrm_distance, dtype: float64

# %%
seg_osrm_dis_agg = df.groupby('trip_uuid')['segment_osrm_distance'].sum()
seg_osrm_dis_agg.head()
# Out:
# trip_uuid
# trip-153671041653548748    1320.4733
# trip-153671042288605164      84.1894
# trip-153671043369099517    2545.2678
# trip-153671046011330457      19.8766
# trip-153671052974046625     146.7919
# Name: segment_osrm_distance, dtype: float64

# %%
f_stats, p_value = ttest_rel(osrm_dis_agg.values, seg_osrm_dis_agg.values)
print("t-statistic:", t_stat)
print("p-value:", p_value)
# Out:
# t-statistic: 651.1832057297116
# p-value: 2.1753879024067997e-192

# %%
if p_value > 0.05:
    print("The distributions are not significantly different.")
else:
    print("The distributions are significantly different.")
# Out:
# The distributions are significantly different.

# %%
plt.figure(figsize=(10, 6))
plt.plot(osrm_dis_agg.values.ravel()[:25], label='Osrm distance', marker='o')
plt.plot(seg_osrm_dis_agg.values.ravel()[:25], label='Segment osrm Distance', marker='x')
plt.title("Line Plot: Osrm distance vs Segment osrm Distance (First 25 Trips)")
plt.xlabel("Trip Index")
plt.ylabel("Distance")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Do hypothesis testing/ visual analysis between osrm time aggregated value and segment osrm time aggregated value (aggregated values are the values you’ll get after merging the rows on the basis of trip_uuid)**

# %%
segment_osrm_time_agg = df.groupby('trip_uuid')['segment_osrm_time'].sum()
segment_osrm_time_agg.head()
# Out:
# trip_uuid
# trip-153671041653548748    1008.0
# trip-153671042288605164      65.0
# trip-153671043369099517    1941.0
# trip-153671046011330457      16.0
# trip-153671052974046625     115.0
# Name: segment_osrm_time, dtype: float64

# %%
f_stats, p_value = ttest_rel(osrm_time_agg.values, segment_osrm_time_agg.values)
print("t-statistic:", t_stat)
print("p-value:", p_value)
# Out:
# t-statistic: 651.1832057297116
# p-value: 1.0892807362104113e-195

# %%
if p_value > 0.05:
    print("The distributions are not significantly different.")
else:
    print("The distributions are significantly different.")
# Out:
# The distributions are significantly different.

# %%
plt.figure(figsize=(10, 6))
plt.plot(osrm_time_agg.values.ravel()[:25], label='osrm Time', marker='o')
plt.plot(segment_osrm_time_agg.values.ravel()[:25], label='Segment osrm Time', marker='x')
plt.title("Line Plot: osrm time vs Segment osrm Time (First 25 Trips)")
plt.xlabel("Trip Index")
plt.ylabel("Time")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Find outliers in the numerical variables (you might find outliers in almost all the variables), and check it using visual analysis**

# %%
# Assume df is your DataFrame
numerical_cols = df.select_dtypes(include=[np.number]).columns

outlier_summary = {}

for col in numerical_cols:
    q1 = np.percentile(df[col], 25)
    q3 = np.percentile(df[col], 75)
    iqr = q3 - q1

    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr

    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    outlier_count = len(outliers)

    outlier_summary[col] = outlier_count

# Print outlier count per column
total_counts = 0
for col, count in outlier_summary.items():
    total_counts += count
    print(f"{col}: {count} outliers")

print(f'total_counts : {total_counts}')
# Out:
# start_scan_to_end_scan: 373 outliers
# cutoff_factor: 17246 outliers
# actual_distance_to_destination: 17992 outliers
# actual_time: 16633 outliers
# osrm_time: 17603 outliers
# osrm_distance: 17816 outliers
# factor: 11429 outliers
# segment_actual_time: 9298 outliers
# segment_osrm_time: 6378 outliers
# segment_osrm_distance: 4315 outliers
# segment_factor: 13976 outliers
# trip_month: 17518 outliers
# trip_year: 0 outliers
# trip_day: 0 outliers
# trip_time: 0 outliers
# time_taken: 373 outliers
# total_counts : 150950

# %%
plt.figure(figsize=(14, 6))
sns.boxplot(data=df[numerical_cols], orient="h", palette="Set2")
plt.title("Boxplot of Numerical Features")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Handle the outliers using the IQR method**

# %%
num_cols = df.select_dtypes(include=np.number).columns

df_cleaned = df.copy()

for col in num_cols:
    Q1 = np.percentile(df_cleaned[col], 25)
    Q3 = np.percentile(df_cleaned[col], 75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    df_cleaned = df_cleaned[(df_cleaned[col] >= lower_bound) & (df_cleaned[col] <= upper_bound)]

print(f"Original shape: {df.shape}")
print(f"Shape after removing outliers: {df_cleaned.shape}")
# Out:
# Original shape: (144867, 37)
# Shape after removing outliers: (58857, 37)

# %% [markdown]
# **Do one-hot encoding of categorical variables (like route_type)**

# %%
cat_col = df.select_dtypes(include = 'object')
cat_col.head()
# Out:
#        data                                route_schedule_uuid route_type  \
# 0  training  thanos::sroute:eb7bfc78-b351-4c0e-a951-fa3d5c3...    Carting
# 1  training  thanos::sroute:eb7bfc78-b351-4c0e-a951-fa3d5c3...    Carting
# 2  training  thanos::sroute:eb7bfc78-b351-4c0e-a951-fa3d5c3...    Carting
# 3  training  thanos::sroute:eb7bfc78-b351-4c0e-a951-fa3d5c3...    Carting
# 4  training  thanos::sroute:eb7bfc78-b351-4c0e-a951-fa3d5c3...    Carting
#
#                  trip_uuid source_center                 source_name  \
# 0  trip-153741093647649320  IND388121AAA  Anand_VUNagar_DC (Gujarat)
# 1  trip-153741093647649320  IND388121AAA  Anand_VUNagar_DC (Gujarat)
# 2  trip-153741093647649320  IND388121AAA  Anand_VUNagar_DC (Gujarat)
# 3  trip-153741093647649320  IND388121AAA  Anand_VUNagar_DC (Gujarat)
# 4  trip-153741093647649320  IND388121AAA  Anand_VUNagar_DC (Gujarat)
#
#   destination_center               destination_name  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144867 entries, 0 to 144866
# Data columns (total 37 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   data                            144867 non-null  object
#  1   trip_creation_time              144867 non-null  datetime64[ns]
#  2   route_schedule_uuid             144867 non-null  object
#  3   route_type                      144867 non-null  object
#  4   trip_uuid                       144867 non-null  object
#  5   source_center                   144867 non-null  object
#  6   source_name                     144867 non-null  object
#  7   destination_center              144867 non-null  object
#  8   destination_name                144867 non-null  object
#  9   od_start_time                   144867 non-null  datetime64[ns]
#  10  od_end_time                     144867 non-null  datetime64[ns]
# ...

# %%
cat_col = df.select_dtypes(include = 'object')
for i in cat_col:
    print(f'{i} : {df[i].nunique()}')
# Out:
# data : 2
# route_schedule_uuid : 1504
# route_type : 2
# trip_uuid : 14817
# source_center : 1508
# source_name : 1499
# destination_center : 1481
# destination_name : 1469
# destination : 1481
# source : 1508
# destination_city : 32
# destination_place : 1468
# destination_code : 1481
# source_city : 31
# source_place : 1498
# source_code : 1508

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
for col in df[['data', 'route_type']]:
  encoder = OneHotEncoder()
  encoded_data = encoder.fit_transform(df[[col]])
  encoded_df = pd.DataFrame(encoded_data.toarray(), columns=encoder.get_feature_names_out([col]))
  df = pd.concat([df, encoded_df], axis=1)

# %%
df.head()
# Out:
#        data         trip_creation_time  \
# 0  training 2018-09-20 02:35:36.476840
# 1  training 2018-09-20 02:35:36.476840
# 2  training 2018-09-20 02:35:36.476840
# 3  training 2018-09-20 02:35:36.476840
# 4  training 2018-09-20 02:35:36.476840
#
#                                  route_schedule_uuid route_type  \
# 0  thanos::sroute:eb7bfc78-b351-4c0e-a951-fa3d5c3...    Carting
# 1  thanos::sroute:eb7bfc78-b351-4c0e-a951-fa3d5c3...    Carting
# 2  thanos::sroute:eb7bfc78-b351-4c0e-a951-fa3d5c3...    Carting
# 3  thanos::sroute:eb7bfc78-b351-4c0e-a951-fa3d5c3...    Carting
# 4  thanos::sroute:eb7bfc78-b351-4c0e-a951-fa3d5c3...    Carting
#
#                  trip_uuid source_center                 source_name  \
# 0  trip-153741093647649320  IND388121AAA  Anand_VUNagar_DC (Gujarat)
# 1  trip-153741093647649320  IND388121AAA  Anand_VUNagar_DC (Gujarat)
# 2  trip-153741093647649320  IND388121AAA  Anand_VUNagar_DC (Gujarat)
# ...

# %% [markdown]
# **Normalize/ Standardize the numerical features using MinMaxScaler or StandardScaler.**

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

num_cols = df.select_dtypes(include=['int64', 'float64']).columns
df_num = df[num_cols]

scaler = MinMaxScaler()
df_scaled_minmax = pd.DataFrame(scaler.fit_transform(df_num), columns=num_cols)
df = pd.concat([df, df_scaled_minmax], axis=1)

# %%
df.head()
# Out:
#        data         trip_creation_time  \
# 0  training 2018-09-20 02:35:36.476840
# 1  training 2018-09-20 02:35:36.476840
# 2  training 2018-09-20 02:35:36.476840
# 3  training 2018-09-20 02:35:36.476840
# 4  training 2018-09-20 02:35:36.476840
#
#                                  route_schedule_uuid route_type  \
# 0  thanos::sroute:eb7bfc78-b351-4c0e-a951-fa3d5c3...    Carting
# 1  thanos::sroute:eb7bfc78-b351-4c0e-a951-fa3d5c3...    Carting
# 2  thanos::sroute:eb7bfc78-b351-4c0e-a951-fa3d5c3...    Carting
# 3  thanos::sroute:eb7bfc78-b351-4c0e-a951-fa3d5c3...    Carting
# 4  thanos::sroute:eb7bfc78-b351-4c0e-a951-fa3d5c3...    Carting
#
#                  trip_uuid source_center                 source_name  \
# 0  trip-153741093647649320  IND388121AAA  Anand_VUNagar_DC (Gujarat)
# 1  trip-153741093647649320  IND388121AAA  Anand_VUNagar_DC (Gujarat)
# 2  trip-153741093647649320  IND388121AAA  Anand_VUNagar_DC (Gujarat)
# ...
